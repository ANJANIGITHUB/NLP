# %%
### Libraries USed Tensorflow> 2.0  and keras

# %%
##tensorflow >2.0
from tensorflow.keras.preprocessing.text import one_hot

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
vocab_size=10000

# %%
onehot_repr=[one_hot(words,vocab_size) for words in sent]

# %%
onehot_repr
# Out:
# [[7956, 9127, 816, 2517],
#  [7956, 9127, 816, 8889],
#  [7956, 1744, 816, 1549],
#  [6513, 3938, 9991, 4460, 1862],
#  [6513, 3938, 9991, 4460, 9836],
#  [2827, 7956, 4243, 816, 3646],
#  [7172, 5631, 9448, 4460]]

# %% [markdown]
# ### Word Embadding Representation

# %%
from tensorflow.keras.layers import Embedding 
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
set_length=8
embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=set_length)

# %%
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 7956, 9127,  816, 2517],
#        [   0,    0,    0,    0, 7956, 9127,  816, 8889],
#        [   0,    0,    0,    0, 7956, 1744,  816, 1549],
#        [   0,    0,    0, 6513, 3938, 9991, 4460, 1862],
#        [   0,    0,    0, 6513, 3938, 9991, 4460, 9836],
#        [   0,    0,    0, 2827, 7956, 4243,  816, 3646],
#        [   0,    0,    0,    0, 7172, 5631, 9448, 4460]])

# %%
model=Sequential()

# %%
model.add(Embedding(vocab_size,10,input_length=set_length))
# Out:
# WARNING:tensorflow:From C:\Users\akumar4\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From C:\Users\akumar4\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\utils\losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 8, 10)             100000
# =================================================================
# Total params: 100,000
# Trainable params: 100,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# array([[[-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.0358041 , -0.00591692,  0.01840824, -0.02455699,
#           0.01643315,  0.01784236,  0.04914376,  0.0283285 ,
#           0.02991403,  0.02088293],
#         [-0.02932071,  0.01383418, -0.01975195,  0.01420318,
#          -0.04898718, -0.02002957, -0.01568725, -0.0454464 ,
#           0.03447261, -0.03836309],
#         [ 0.04548723,  0.03865751, -0.03899451,  0.04361422,
#           0.02021926,  0.02316976,  0.02654887,  0.03294506,
#          -0.02536224,  0.02751091],
#         [ 0.04163812, -0.0442538 ,  0.02435053, -0.01461907,
#           0.01364395, -0.02830784, -0.02291864,  0.0443345 ,
#           0.01062118, -0.00630244]],
#
#        [[-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.0358041 , -0.00591692,  0.01840824, -0.02455699,
#           0.01643315,  0.01784236,  0.04914376,  0.0283285 ,
#           0.02991403,  0.02088293],
#         [-0.02932071,  0.01383418, -0.01975195,  0.01420318,
#          -0.04898718, -0.02002957, -0.01568725, -0.0454464 ,
#           0.03447261, -0.03836309],
#         [ 0.04548723,  0.03865751, -0.03899451,  0.04361422,
#           0.02021926,  0.02316976,  0.02654887,  0.03294506,
#          -0.02536224,  0.02751091],
#         [ 0.02125638,  0.00212724, -0.02377908,  0.0063758 ,
#           0.00526641, -0.03609377, -0.02490742, -0.01105867,
#           0.00836752, -0.01272612]],
#
#        [[-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.0358041 , -0.00591692,  0.01840824, -0.02455699,
#           0.01643315,  0.01784236,  0.04914376,  0.0283285 ,
#           0.02991403,  0.02088293],
#         [-0.04373601,  0.00438112, -0.00237866,  0.00881205,
#           0.01298361, -0.03363018, -0.00275335, -0.01023393,
#          -0.04761536,  0.00467135],
#         [ 0.04548723,  0.03865751, -0.03899451,  0.04361422,
#           0.02021926,  0.02316976,  0.02654887,  0.03294506,
#          -0.02536224,  0.02751091],
#         [ 0.04464302,  0.04119143, -0.02436292,  0.01482992,
#          -0.03085477, -0.043084  , -0.02502756, -0.00450293,
#           0.04344792,  0.0012393 ]],
#
#        [[-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.02587477, -0.0340146 , -0.0261295 ,  0.04742369,
#          -0.02212862,  0.02680458, -0.04669506, -0.04150278,
#          -0.00121586,  0.03154338],
#         [-0.0147198 , -0.00546007,  0.02937248,  0.01103687,
#           0.00325771,  0.02774019, -0.00075742, -0.03880683,
#           0.03487771, -0.02566761],
#         [ 0.00724947, -0.00579014, -0.02923696,  0.02260581,
#          -0.04786546,  0.01239371, -0.03558107, -0.01946287,
#           0.00608125, -0.0365796 ],
#         [-0.02704617,  0.03507384, -0.00052667,  0.00715073,
#          -0.04308432, -0.03435162,  0.00518538,  0.01587336,
#          -0.02847096,  0.03751374],
#         [-0.01452462, -0.0257286 ,  0.01670739, -0.04463164,
#          -0.00676041,  0.03354064,  0.00738243,  0.01617339,
#           0.03549612,  0.04814433]],
#
#        [[-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.02587477, -0.0340146 , -0.0261295 ,  0.04742369,
#          -0.02212862,  0.02680458, -0.04669506, -0.04150278,
#          -0.00121586,  0.03154338],
#         [-0.0147198 , -0.00546007,  0.02937248,  0.01103687,
#           0.00325771,  0.02774019, -0.00075742, -0.03880683,
#           0.03487771, -0.02566761],
#         [ 0.00724947, -0.00579014, -0.02923696,  0.02260581,
#          -0.04786546,  0.01239371, -0.03558107, -0.01946287,
#           0.00608125, -0.0365796 ],
#         [-0.02704617,  0.03507384, -0.00052667,  0.00715073,
#          -0.04308432, -0.03435162,  0.00518538,  0.01587336,
#          -0.02847096,  0.03751374],
#         [-0.01565865, -0.04387673,  0.01532403,  0.01619336,
#           0.00115122, -0.04815009,  0.04241304,  0.03159178,
#           0.01977647,  0.04146216]],
#
#        [[-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03637279,  0.01270357, -0.04903119,  0.01254452,
#           0.02879348,  0.03643644, -0.01428105,  0.04928276,
#          -0.02992407,  0.01348643],
#         [-0.0358041 , -0.00591692,  0.01840824, -0.02455699,
#           0.01643315,  0.01784236,  0.04914376,  0.0283285 ,
#           0.02991403,  0.02088293],
#         [ 0.03685756, -0.04188777,  0.04542601, -0.00609685,
#           0.0344142 , -0.0096794 ,  0.03748623,  0.01695259,
#           0.01120143,  0.01999805],
#         [ 0.04548723,  0.03865751, -0.03899451,  0.04361422,
#           0.02021926,  0.02316976,  0.02654887,  0.03294506,
#          -0.02536224,  0.02751091],
#         [ 0.02787408,  0.03051055,  0.03857442,  0.03268244,
#           0.04549732,  0.00097104, -0.01871658, -0.01083739,
#          -0.04951464,  0.01433126]],
#
#        [[-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,
#           0.02887997, -0.01450024, -0.00787168,  0.02140123,
#           0.0340798 ,  0.00115161],
#         [ 0.0038415 , -0.01078566,  0.03703464, -0.02830907,
#          -0.03988028, -0.03162848, -0.0068213 ,  0.01067215,
#          -0.0404155 , -0.00547392],
#         [ 0.00046494, -0.00516746, -0.01172702,  0.03899738,
#           0.02475457,  0.02487383, -0.01563517,  0.01103103,
#           0.02053482,  0.03687321],
#         [ 0.04403448,  0.00364184,  0.02057323,  0.02240516,
#          -0.03390852, -0.04977888,  0.02526725,  0.02413276,
#           0.04949701, -0.01641626],
#         [-0.02704617,  0.03507384, -0.00052667,  0.00715073,
#          -0.04308432, -0.03435162,  0.00518538,  0.01587336,
#          -0.02847096,  0.03751374]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 7956, 9127,  816, 2517])

# %%
model.predict(embedded_docs)[0]
# Out:
# array([[-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,  0.02887997,
#         -0.01450024, -0.00787168,  0.02140123,  0.0340798 ,  0.00115161],
#        [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,  0.02887997,
#         -0.01450024, -0.00787168,  0.02140123,  0.0340798 ,  0.00115161],
#        [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,  0.02887997,
#         -0.01450024, -0.00787168,  0.02140123,  0.0340798 ,  0.00115161],
#        [-0.03173004, -0.01944615, -0.0211279 ,  0.0313856 ,  0.02887997,
#         -0.01450024, -0.00787168,  0.02140123,  0.0340798 ,  0.00115161],
#        [-0.0358041 , -0.00591692,  0.01840824, -0.02455699,  0.01643315,
#          0.01784236,  0.04914376,  0.0283285 ,  0.02991403,  0.02088293],
#        [-0.02932071,  0.01383418, -0.01975195,  0.01420318, -0.04898718,
#         -0.02002957, -0.01568725, -0.0454464 ,  0.03447261, -0.03836309],
#        [ 0.04548723,  0.03865751, -0.03899451,  0.04361422,  0.02021926,
#          0.02316976,  0.02654887,  0.03294506, -0.02536224,  0.02751091],
#        [ 0.04163812, -0.0442538 ,  0.02435053, -0.01461907,  0.01364395,
#         -0.02830784, -0.02291864,  0.0443345 ,  0.01062118, -0.00630244]],
#       dtype=float32)
